# %%
import pandas as pd
import numpy as np 
from keras.preprocessing.text import text_to_word_sequence, one_hot, hashing_trick, Tokenizer

# %% [markdown]
# # Data Prep
#
# We start by loading the data, splitting the comments to be individual data points.

# %%
mbti_data_original = pd.read_csv('mbti_data.csv')
mbti_data_original.iloc[2,1].split('|||')
mbti_split = pd.DataFrame()

for x in range(len(mbti_data_original)):
    row_data = mbti_data_original.iloc[x,1].split('|||') # The ||| is how the data is split in the file 
    p_type = mbti_data_original.iloc[x,0]
    split_data_entry = pd.DataFrame({'type' : p_type, 'comment' : row_data, 'user' : x})
    mbti_split = pd.concat([mbti_split, split_data_entry])

mbti_split.shape
# Out:
# (422845, 3)

# %% [markdown]
# We next split the comments into word vectors, find the total number of unique words then use the md5 hash function to create an integer hash of each of the words

# %%
import re
#remove url comments since they won't relate well to the yelp data 
mbti_split['comment'] = mbti_split['comment'].apply(lambda x : re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', '', x, flags=re.MULTILINE) )
mbti_split['comment'].replace('', np.nan, inplace=True)
mbti_split.dropna(subset=['comment'], inplace=True)

#vectorise
mbti_split['seq_comment'] = mbti_split['comment'].apply(text_to_word_sequence)
vocab_size = len(mbti_split['seq_comment'].apply(pd.Series).stack().unique())
mbti_split['vectorised'] = mbti_split['comment'].apply(lambda x : hashing_trick(x, round(vocab_size*1.5), hash_function= 'md5'))

# %%
mbti_split.head(200)
# Out:
#     type                                            comment  user  \
# 0   INFJ                                                  '     0
# 2   INFJ  enfp and intj moments    sportscenter not top ...     0
# 3   INFJ  What has been the most life-changing experienc...     0
# 4   INFJ                       On repeat for most of today.     0
# 5   INFJ               May the PerC Experience immerse you.     0
# 6   INFJ  The last thing my INFJ friend posted on his fa...     0
# 7   INFJ  Hello ENFJ7. Sorry to hear of your distress. I...     0
# 8   INFJ                               84389  84390     ...     0
# 9   INFJ                                 Welcome and stuff.     0
# 10  INFJ                                  Game. Set. Match.     0
# 11  INFJ  Prozac, wellbrutin, at least thirty minutes of...     0
# 12  INFJ  Basically come up with three items you've dete...     0
# 13  INFJ  All things in moderation.  Sims is indeed a vi...     0
# 14  INFJ  Dear ENFP:  What were your favorite video game...     0
# 16  INFJ                   It appears to be too late. :sad:     0
# 17  INFJ            There's someone out there for everyone.     0
# 18  INFJ     Wait... I thought confidence was a good thing.     0
# 19  INFJ  I just cherish the time of solitude b/c i reve...     0
# 20  INFJ  Yo entp ladies... if you're into a complimenta...     0
# 21  INFJ  ... when your main social outlet is xbox live ...     0
# 22  INFJ            I really dig the part from 1:46 to 2:50     0
# 24  INFJ      Banned because this thread requires it of me.     0
# 25  INFJ  Get high in backyard, roast and eat marshmello...     0
# 29  INFJ  Banned for too many b's in that sentence. How ...     0
# 30  INFJ  Banned for watching movies in the corner with ...     0
# 31  INFJ  Banned because Health class clearly taught you...     0
# 32  INFJ                Banned for a whole host of reasons!     0
# 34  INFJ  1) Two baby deer on left and right munching on...     0
# 35  INFJ  a pokemon world  an infj society  everyone bec...     0
# 36  INFJ                                              49142     0
# ..   ...                                                ...   ...
# 37  INTJ  And this was sort of my thought process. The i...     3
# 38  INTJ  Oh my...  I am quite crushable, huh?  Back atcha.     3
# 39  INTJ     I was, but it's 5am. I'll take what I can get.     3
# 40  INTJ  I wanted to come up with something clever, but...     3
# 41  INTJ  So then why do you even bother asking if you'v...     3
# 42  INTJ   Wasn't sure I listened to sx music until now.        3
# 43  INTJ  INFP messaged me with a picture of herself bef...     3
# 44  INTJ  Either way, you see my point. The actual rarit...     3
# 45  INTJ  WOW my math was off! I literally just said num...     3
# 46  INTJ  Rarity in the context of the entire planet is ...     3
# 47  INTJ  One could say that whatever the culmination of...     3
# 48  INTJ  I would agree, however, those that profess to ...     3
# 49  INTJ                                              Lol.'     3
# 0   ENTJ                                     'You're fired.     4
# 1   ENTJ  That's another silly misconception. That appro...     4
# 2   ENTJ  But guys... he REALLY wants to go on a super-d...     4
# 3   ENTJ         Never mind. Just go on permanent vacation.     4
# 4   ENTJ  Two months? I wouldn't be crazy about the idea...     4
# 5   ENTJ  Lol. Its not like our views were unsolicited. ...     4
# 6   ENTJ  Sometimes I just really like impoverished rap ...     4
# 7   ENTJ  I probably would have lost it too. His stonewa...     4
# 8   ENTJ  I would have just taken the project and gave t...     4
# 9   ENTJ  The court deposition wasn't a skit. That actua...     4
# 10  ENTJ                                       And her ass.     4
# 11  ENTJ  I'll flirt a woman for a piece of candy at the...     4
# 13  ENTJ  Yes. In the comments she gave more info, then ...     4
# 14  ENTJ                        What's this we thing about?     4
# 15  ENTJ  Callaendia are you the same INFP girl who was ...     4
# 16  ENTJ                                                 3X     4
# 17  ENTJ  11/25 I do not modify myself to suit others, h...     4
#
#                                           seq_comment  \
# 0                                                 [']
# 2   [enfp, and, intj, moments, sportscenter, not, ...
# 3   [what, has, been, the, most, life, changing, e...
# 4                  [on, repeat, for, most, of, today]
# 5          [may, the, perc, experience, immerse, you]
# 6   [the, last, thing, my, infj, friend, posted, o...
# 7   [hello, enfj7, sorry, to, hear, of, your, dist...
# 8                                      [84389, 84390]
# 9                               [welcome, and, stuff]
# 10                                 [game, set, match]
# 11  [prozac, wellbrutin, at, least, thirty, minute...
# 12  [basically, come, up, with, three, items, you'...
# 13  [all, things, in, moderation, sims, is, indeed...
# 14  [dear, enfp, what, were, your, favorite, video...
# 16              [it, appears, to, be, too, late, sad]
# 17      [there's, someone, out, there, for, everyone]
# 18  [wait, i, thought, confidence, was, a, good, t...
# 19  [i, just, cherish, the, time, of, solitude, b,...
# 20  [yo, entp, ladies, if, you're, into, a, compli...
# 21  [when, your, main, social, outlet, is, xbox, l...
# 22  [i, really, dig, the, part, from, 1, 46, to, 2...
# 24  [banned, because, this, thread, requires, it, ...
# 25  [get, high, in, backyard, roast, and, eat, mar...
# 29  [banned, for, too, many, b's, in, that, senten...
# 30  [banned, for, watching, movies, in, the, corne...
# 31  [banned, because, health, class, clearly, taug...
# 32         [banned, for, a, whole, host, of, reasons]
# 34  [1, two, baby, deer, on, left, and, right, mun...
# 35  [a, pokemon, world, an, infj, society, everyon...
# 36                                            [49142]
# ..                                                ...
# 37  [and, this, was, sort, of, my, thought, proces...
# 38  [oh, my, i, am, quite, crushable, huh, back, a...
# 39  [i, was, but, it's, 5am, i'll, take, what, i, ...
# 40  [i, wanted, to, come, up, with, something, cle...
# 41  [so, then, why, do, you, even, bother, asking,...
# 42  [wasn't, sure, i, listened, to, sx, music, unt...
# 43  [infp, messaged, me, with, a, picture, of, her...
# 44  [either, way, you, see, my, point, the, actual...
# 45  [wow, my, math, was, off, i, literally, just, ...
# 46  [rarity, in, the, context, of, the, entire, pl...
# 47  [one, could, say, that, whatever, the, culmina...
# 48  [i, would, agree, however, those, that, profes...
# 49                                           [lol, ']
# 0                                    ['you're, fired]
# 1   [that's, another, silly, misconception, that, ...
# 2   [but, guys, he, really, wants, to, go, on, a, ...
# 3    [never, mind, just, go, on, permanent, vacation]
# 4   [two, months, i, wouldn't, be, crazy, about, t...
# 5   [lol, its, not, like, our, views, were, unsoli...
# 6   [sometimes, i, just, really, like, impoverishe...
# 7   [i, probably, would, have, lost, it, too, his,...
# 8   [i, would, have, just, taken, the, project, an...
# 9   [the, court, deposition, wasn't, a, skit, that...
# 10                                    [and, her, ass]
# 11  [i'll, flirt, a, woman, for, a, piece, of, can...
# 13  [yes, in, the, comments, she, gave, more, info...
# 14                   [what's, this, we, thing, about]
# 15  [callaendia, are, you, the, same, infp, girl, ...
# 16                                               [3x]
# 17  [11, 25, i, do, not, modify, myself, to, suit,...
#
#                                            vectorised
# 0                                             [73200]
# 2   [36362, 147875, 92936, 81320, 67477, 47566, 13...
# 3   [97637, 175511, 33942, 50366, 18468, 102440, 1...
# 4         [135915, 88078, 66714, 18468, 28759, 33041]
# 5       [125654, 50366, 167561, 136920, 71501, 40536]
# 6   [50366, 121498, 7594, 59001, 484, 57573, 17385...
# 7   [25695, 19303, 101691, 118588, 157170, 28759, ...
# 8                                     [150130, 88496]
# 9                              [45424, 147875, 78425]
# 10                           [119708, 116879, 148401]
# 11  [106562, 23058, 8806, 91169, 77082, 17639, 287...
# 12  [45510, 111985, 95855, 63080, 104675, 42867, 4...
# 13  [146942, 2254, 89668, 94610, 22320, 154320, 76...
# 14  [1377, 36362, 97637, 25527, 135093, 166131, 10...
# 16  [133453, 102460, 118588, 159724, 47181, 7008, ...
# 17         [92178, 43796, 37934, 174785, 66714, 7420]
# 18  [53950, 40662, 16476, 11715, 71418, 56106, 438...
# 19  [40662, 167391, 60841, 50366, 158850, 28759, 3...
# 20  [152176, 141805, 63508, 159208, 99568, 77535, ...
# 21  [92608, 135093, 72232, 33667, 10305, 154320, 1...
# 22  [40662, 174164, 124080, 50366, 92281, 21903, 1...
# 24  [25700, 172523, 16695, 61683, 169746, 133453, ...
# 25  [30524, 106776, 89668, 130806, 132756, 147875,...
# 29  [25700, 66714, 47181, 61493, 2024, 89668, 8304...
# 30  [25700, 66714, 10521, 90421, 89668, 50366, 124...
# 31  [25700, 172523, 19145, 115066, 52572, 147444, ...
# 32  [25700, 66714, 56106, 61388, 156275, 28759, 71...
# 34  [177404, 67296, 64562, 164045, 135915, 22945, ...
# 35  [56106, 118595, 144272, 161951, 484, 85181, 74...
# 36                                             [9869]
# ..                                                ...
# 37  [147875, 16695, 71418, 3616, 28759, 59001, 164...
# 38  [89232, 59001, 40662, 40662, 71238, 173619, 56...
# 39  [40662, 71418, 82976, 131973, 23881, 177023, 1...
# 40  [40662, 31067, 118588, 111985, 95855, 63080, 1...
# 41  [165497, 165201, 49382, 172394, 40536, 125715,...
# 42  [122181, 128398, 40662, 176856, 118588, 91819,...
# 43  [107502, 34720, 104491, 63080, 56106, 64659, 2...
# 44  [89879, 39285, 40536, 51449, 59001, 131892, 50...
# 45  [150140, 59001, 29353, 71418, 166085, 40662, 1...
# 46  [129297, 89668, 50366, 115282, 28759, 50366, 3...
# 47  [153309, 52292, 113920, 83048, 131511, 50366, ...
# 48  [40662, 50621, 123254, 139638, 101857, 83048, ...
# 49                                     [83176, 73200]
# 0                                    [166344, 162361]
# 1   [94974, 95177, 670, 101034, 83048, 129531, 154...
# 2   [82976, 36901, 52077, 174164, 40869, 118588, 1...
# 3   [125213, 9816, 167391, 152582, 135915, 159408,...
# 4   [67296, 105509, 40662, 47412, 159724, 178346, ...
# 5   [83176, 84402, 47566, 41184, 54307, 44246, 255...
# 6   [74420, 40662, 167391, 174164, 41184, 37702, 9...
# 7   [40662, 132136, 50621, 80692, 16934, 133453, 4...
# 8   [40662, 50621, 80692, 167391, 91168, 50366, 30...
# 9   [50366, 83988, 10305, 122181, 56106, 81194, 83...
# 10                             [147875, 78194, 89893]
# 11  [177023, 171256, 56106, 86185, 66714, 56106, 1...
# 13  [12989, 89668, 50366, 31069, 11471, 125177, 15...
# 14                [90683, 16695, 158532, 7594, 31180]
# 15  [179544, 2476, 40536, 50366, 28593, 107502, 67...
# 16                                           [178821]
# 17  [23795, 969, 40662, 172394, 47566, 58639, 7072...
#
# [200 rows x 5 columns]

# %%
mbti_split.to_csv('mbti_data_preprocessed.csv') # writing to csv to save re-splitting

# %%
#Export a vocab list to be combined with the yelp vocab
words = mbti_split['seq_comment'].apply(pd.Series).stack().unique()
np.savetxt("vocab_list_mbti.csv", words, delimiter=",", fmt='%s')
