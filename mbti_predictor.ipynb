# %%
import pandas as pd
import numpy as np 
from keras.preprocessing.text import text_to_word_sequence, one_hot, hashing_trick, Tokenizer

# %% [markdown]
# # Data Prep
#
# We start by loading the data, splitting the comments to be individual data points.

# %%
mbti_data_original = pd.read_csv('mbti_data.csv')
mbti_data_original.iloc[2,1].split('|||')
mbti_split = pd.DataFrame()

for x in range(len(mbti_data_original)):
    row_data = mbti_data_original.iloc[x,1].split('|||') # The ||| is how the data is split in the file 
    p_type = mbti_data_original.iloc[x,0]
    split_data_entry = pd.DataFrame({'type' : p_type, 'comment' : row_data})
    mbti_split = pd.concat([mbti_split, split_data_entry])

mbti_split.shape

# %% [markdown]
# We next split the comments into word vectors, find the total number of unique words then use the md5 hash function to create an integer hash of each of the words

# %%
mbti_split['seq_comment'] = mbti_split['comment'].apply(text_to_word_sequence)
vocab_size = len(mbti_split['seq_comment'].apply(pd.Series).stack().unique())
mbti_split['vectorised'] = mbti_split['comment'].apply(lambda x : hashing_trick(x, round(vocab_size*1.5), hash_function= 'md5'))
mbti_split.to_csv('mbti_data_preprocessed.csv') # writing to csv to save re-splitting

# %%
mbti_split.head(20)
# Out:
#     type                                            comment  \
# 0   INFJ        'http://www.youtube.com/watch?v=qsXHcwe3krw
# 1   INFJ  http://41.media.tumblr.com/tumblr_lfouy03PMA1q...
# 2   INFJ  enfp and intj moments  https://www.youtube.com...
# 3   INFJ  What has been the most life-changing experienc...
# 4   INFJ  http://www.youtube.com/watch?v=vXZeYwwRDw8   h...
# 5   INFJ               May the PerC Experience immerse you.
# 6   INFJ  The last thing my INFJ friend posted on his fa...
# 7   INFJ  Hello ENFJ7. Sorry to hear of your distress. I...
# 8   INFJ  84389  84390  http://wallpaperpassion.com/uplo...
# 9   INFJ                                 Welcome and stuff.
# 10  INFJ  http://playeressence.com/wp-content/uploads/20...
# 11  INFJ  Prozac, wellbrutin, at least thirty minutes of...
# 12  INFJ  Basically come up with three items you've dete...
# 13  INFJ  All things in moderation.  Sims is indeed a vi...
# 14  INFJ  Dear ENFP:  What were your favorite video game...
# 15  INFJ        https://www.youtube.com/watch?v=QyPqT8umzmY
# 16  INFJ                   It appears to be too late. :sad:
# 17  INFJ            There's someone out there for everyone.
# 18  INFJ     Wait... I thought confidence was a good thing.
# 19  INFJ  I just cherish the time of solitude b/c i reve...
#
#                                           seq_comment  \
# 0   ['http, www, youtube, com, watch, v, qsxhcwe3krw]
# 1   [http, 41, media, tumblr, com, tumblr, lfouy03...
# 2   [enfp, and, intj, moments, https, www, youtube...
# 3   [what, has, been, the, most, life, changing, e...
# 4   [http, www, youtube, com, watch, v, vxzeywwrdw...
# 5          [may, the, perc, experience, immerse, you]
# 6   [the, last, thing, my, infj, friend, posted, o...
# 7   [hello, enfj7, sorry, to, hear, of, your, dist...
# 8   [84389, 84390, http, wallpaperpassion, com, up...
# 9                               [welcome, and, stuff]
# 10  [http, playeressence, com, wp, content, upload...
# 11  [prozac, wellbrutin, at, least, thirty, minute...
# 12  [basically, come, up, with, three, items, you'...
# 13  [all, things, in, moderation, sims, is, indeed...
# 14  [dear, enfp, what, were, your, favorite, video...
# 15  [https, www, youtube, com, watch, v, qypqt8umzmy]
# 16              [it, appears, to, be, too, late, sad]
# 17      [there's, someone, out, there, for, everyone]
# 18  [wait, i, thought, confidence, was, a, good, t...
# 19  [i, just, cherish, the, time, of, solitude, b,...
#
#                                            vectorised
# 0   [143816, 59450, 226082, 7001, 132351, 102419, ...
# 1   [175925, 189097, 48657, 41483, 7001, 41483, 21...
# 2   [140754, 47785, 67528, 205490, 206138, 59450, ...
# 3   [119391, 57549, 225842, 202460, 54076, 199652,...
# 4   [175925, 59450, 226082, 7001, 132351, 102419, ...
# 5      [130188, 202460, 33911, 208574, 152847, 93270]
# 6   [202460, 118594, 136754, 55685, 6464, 239723, ...
# 7   [102515, 226095, 63209, 83454, 8076, 108281, 2...
# 8   [70200, 108404, 175925, 140775, 7001, 148808, ...
# 9                              [97028, 47785, 144275]
# 10  [175925, 82925, 7001, 74792, 25766, 53232, 234...
# 11  [134818, 170372, 231294, 178529, 174452, 11348...
# 12  [142398, 34089, 196237, 31258, 217813, 96373, ...
# 13  [125170, 130684, 149640, 155862, 131252, 16270...
# 14  [121991, 140754, 119391, 116575, 211785, 96761...
# 15  [206138, 59450, 226082, 7001, 132351, 102419, ...
# 16  [136817, 82710, 83454, 131602, 157977, 170644,...
# 17      [195468, 117150, 230650, 74439, 37300, 93556]
# 18  [223844, 95218, 150860, 144277, 143618, 166818...
# 19  [95218, 168901, 101787, 202460, 67732, 108281,...

# %%
vocab_size
