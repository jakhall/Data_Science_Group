# %%
#importing json tp read in data
import json
from pprint import pprint

import pandas as pd

# %%
#opening json file
with open('yelp_academic_dataset_business.json',encoding="utf8") as data_file:
    number = next(data_file).strip()
    data = [json.loads(line) for line in data_file]

# %%
#Collecting busines id for city values
#creating lists to store each city and business id
Las_vegas = []
Toronto = []
BusinessIds = []

#looping to get the recordds for Las Vegas and Toronto cities
for i in range(len(data)):
    if data[i]['city'] == 'Las Vegas':
        Las_vegas.append(i)
        
    if data[i]['city'] == 'Toronto':
        Toronto.append(i) 
 
#checking length is reasonable
print(len(Las_vegas))
print(len(Toronto))

#putting the businessids into one list
for i in range(len(Las_vegas)):
    BusinessIds.append(data[Las_vegas[i]]['business_id'])
    
for i in range(len(Toronto)):
    BusinessIds.append(data[Toronto[i]]['business_id'])

Filtered_Business_Ids = list(set(BusinessIds))

print(len(Filtered_Business_Ids))



#for i in range(len(data)):
#    print(data[i]['city'])
# Out:
# 28865
# 18233
# 47098

# %%
#output businessids into a json file


Business_ids = json.dumps({'Business_ids': Filtered_Business_Ids})

with open('Business_ids.csv', 'w') as outfile:
    json.dump(Business_ids, outfile)

# %%
with open('Business_ids.json') as f:
    data2 = json.load(f)

# %%
data2
# Out:
# '{"Business_ids": ["gS0CcaNcmiU18nLqqELhUQ", "Ta8nRU_oUzK60HlMWtayEA", "SYes6mbB7pmimyFSiaXT0Q", "juovUm_s6zYn-Hkke_sctw", "GyXSPlq4aj0Uxm-UJYnGCA", "NYzF9fUr1Oeh3oVEh7BTNA", "2m4092MsMzEHkuxodaj6-g", "mORvJviGBgbJ5Woui-FcOA", "-J6FVdY9pSgAdFmmalO-pQ", "CUTPrmUAkFSE5TJqqCPTQw", "J7EUrh1q3lgENaoTrHZl_w", "cbfbKzpktWRr9y1Tm7nOBQ", "95-TyX4V1tR62tOzfvSm8Q", "6FLrYVqKnlC_XXDAG02ZYA", "EzvQSacRpQhFU_p8NgiVJw", "x84c7qW3iiHTSZZzZMlP1g", "fA8iHbz9x7y9OaVzCv3rbA", "1zrCYNcoBRO0ePhfuNyoCQ", "DJwotSDp_2oqFqEwA6KHtQ", "K80Rbckjt9QdBghUhAc0eA", "ziGwa9EEOHMaPWbdp8tSDg", "cyU4Md3JUDNXsOVz4hFkgA", "qi-zm_G6qyxOybAx1VQ30A", "z9SjyM0Ixr1ud8zI7Y93-A", "IMuR55Sb45iq1q25AKkQhw", "w19nAzC69-AppXp8psaFFg", "BflNpVLfFQujE5uBHUgcFg", "qbNlcvt5Z1KGbzlw_LqaIA", "i2K9ZUKmukzeGBJ98f65gw", "Chgj7xcjgzexBZNGATfuyQ", "6zKU06XeCBdRDnzgNB5NmQ", "dtksMZi0MU6bp6xfUOzwbw", "vRdSJlcDPT1VOxAE0mD2BA", "5